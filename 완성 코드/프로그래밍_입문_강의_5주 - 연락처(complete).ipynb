# %%
# add_contact 함수 선언
def add_contact():

    # name, num, address 변수에 각각 이름, 연락처, 주소를 입력받고 할당
    name, num, address = input("이름: "), input("전화번호: "), input("주소: ")

    # contact_book에 dictionary 형태로 자료 추가(append)
    # dictionary key는 "name", "num", "address"
    dic = {"name": name, "num": num, "address": address}
    contact_book.append(dic)

# %%
# search_contact 함수 선언
def search_contact():

    # 이름을 입력받아 name 변수에 할당
    name = input("이름: ")

    # contact_book의 내용을 contact라는 임시변수로 탐색
    for contact in contact_book:

        # contact의 "name"과 name 변수의 값이 같으면 contact의 내용물 출력
        # f"이름: {contact['name']}, 연락처: {contact['num']}, 주소: {contact['address']}"
        if contact["name"] == name:
            print(f"이름: {contact['name']}, \
            연락처: {contact['num']}, \
            주소: {contact['address']}")

# %%
# view_all_contact 함수 선언
def view_all_contact():

    # contact_book의 내용을 contact라는 임시변수로 탐색
    for contact in contact_book:

        # contact의 내용물 출력
        # f"이름: {contact['name']}, 연락처: {contact['num']}, 주소: {contact['address']}"
        print(f"이름: {contact['name']}, 연락처: {contact['num']}, 주소: {contact['address']}")

# %%
# remove_contact 함수 선언
def remove_contact():

    # 삭제할 이름을 입력받아 name 변수에 할당
    name = input("삭제할 이름: ")

    # contact_book의 내용을 contact라는 임시변수로 탐색
    for contact in contact_book:

        # contact의 "name"과 name이 다르다면 무시(continue)
        if not contact["name"] == name:
            continue


        # 같다면 contact 정보를 출력
        # f"이름: {contact['name']}, 연락처: {contact['num']}, 주소: {contact['address']}"
        print(f"이름: {contact['name']}, 연락처: {contact['num']}, 주소: {contact['address']}")

        # 삭제할 지 묻고 대답이 "y"라면 contact_book에서 contact를 삭제하고(List.remove() 메서드 이용),
        # "삭제되었습니다." 출력하고 반복 종료(break)
        answer = input("삭제할까요? (y / n) ")
        if answer.upper() == "Y":
            contact_book.remove(contact)

# %%
# clear_contact 함수 선언
def clear_contact():

    # 모든 연락처를 삭제할지 묻고, 대답이 "y"라면
    # contact_book 의 내용 모두 삭제 및 초기화
    answer = input("모두 삭제할까요? (y / n)")

    if answer.lower() == "y":
        contact_book.clear()
        print("모두 삭제했습니다.")

# %%
# 연락처를 저장할 list를 만들어 book 함수에 할당
contact_book = [{"name": "홍길동", "num": "010-1234-1234", "address": "부산광역시 해운대구 우동"},
                {"name": "임꺽정", "num": "010-7845-9685", "address": "경기도 수원시 영통구"},
                {"name": "이자겸", "num": "010-6485-5831", "address": "서울 특별시 종로구"}]

# 무한 반복
while 1:

    # 메뉴를 소개하고 어떤 메뉴를 선택했는지를 입력받아 menu 변수에 할당(문자열)
    print("\n=================\n")
    print("1 연락처 추가")
    print("2 연락처 검색")
    print("3 연락처 모두 보기")
    print("4 연락처 삭제")
    print("5 연락처 초기화")
    print("Q 종료")
    menu = input("명령 선택: ")

    # menu가 "1"이면 add_contact 함수 호출
    if menu == "1":
        add_contact()

    # menu가 "2"면 search_contact 함수 호출
    elif menu == "2":
        search_contact()

    # menu가 "3"이면 view_all_contact 함수 호출
    elif menu == "3":
        view_all_contact()

    # menu가 "4"이면 remove_contact 함수 호출
    elif menu == "4":
        remove_contact()

    # menu가 "5"면 clear_contact 함수 호출
    elif menu == "5":
        clear_contact()

    # menu를 대문자로 바꾼 값이 "Q"이면 "종료합니다"를 출력하고, 반복 종료(break)
    elif menu.upper() == "Q":
        print("종료합니다.")
        break
# Out:
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 3
# 이름: 홍길동, 연락처: 010-1234-1234, 주소: 부산광역시 해운대구 우동
# 이름: 임꺽정, 연락처: 010-7845-9685, 주소: 경기도 수원시 영통구
# 이름: 이자겸, 연락처: 010-6485-5831, 주소: 서울 특별시 종로구
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 1
# 이름: 김지원
# 전화번호: 1234
# 주소: 우리집
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 3
# 이름: 홍길동, 연락처: 010-1234-1234, 주소: 부산광역시 해운대구 우동
# 이름: 임꺽정, 연락처: 010-7845-9685, 주소: 경기도 수원시 영통구
# 이름: 이자겸, 연락처: 010-6485-5831, 주소: 서울 특별시 종로구
# 이름: 김지원, 연락처: 1234, 주소: 우리집
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 4
# 삭제할 이름: 김지원
# 이름: 김지원, 연락처: 1234, 주소: 우리집
# 삭제할까요? (y / n) y
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 3
# 이름: 홍길동, 연락처: 010-1234-1234, 주소: 부산광역시 해운대구 우동
# 이름: 임꺽정, 연락처: 010-7845-9685, 주소: 경기도 수원시 영통구
# 이름: 이자겸, 연락처: 010-6485-5831, 주소: 서울 특별시 종로구
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 5
# 모두 삭제할까요? (y / n)y
# 모두 삭제했습니다.
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: 3
#
# =================
#
# 1 연락처 추가
# 2 연락처 검색
# 3 연락처 모두 보기
# 4 연락처 삭제
# 5 연락처 초기화
# Q 종료
# 명령 선택: q
# 종료합니다.
